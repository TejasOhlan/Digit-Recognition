# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasOhlan/Digit-Recognition/blob/main/testing_digit_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##processing image to be predicted

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e921566-f546-49d7-9c16-af4eca94bda0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e921566-f546-49d7-9c16-af4eca94bda0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4.jpeg to 4.jpeg

# %%
df = pd.read_csv("paste the path you copied here")

# %%
imag = "4.jpeg" #@param {type:"string"}
import matplotlib.pyplot as plt
img = plt.imread(imag)
plt.imshow(img)
from PIL import Image
image = Image.open(imag)
image.show()
print(image.format)
print(image.mode)
print(image.size)
# Out:
# JPEG
# RGB
# (524, 596)

# %%
new2 = image.resize((28,28))
new2.save('4resized.jpeg')
plt.imshow(new2)

# %%
#new2 = new2.reshape((1,28*28))
#cant do it like this..first you have to add image in numpy array

# %%
from keras.preprocessing.image import img_to_array
new2 = img_to_array(new2)
print(type(new2))
print(new2.dtype)
print(new2.shape)
#using 'Image' library to convert new2 in grayscale
import numpy as np
new2 = np.array(Image.open('4resized.jpeg').convert('L')) 
new2 = new2.reshape(1,28*28)
print(new2.shape)
#print(new2)
# Out:
# <class 'numpy.ndarray'>
# float32
# (28, 28, 3)
# (1, 784)

# %% [markdown]
# ##loading model

# %%
import tensorflow as tf

new2model = tf.keras.models.load_model('myDigitDetectionModel.h5')

# %%
predict = new2model.predict(new2,verbose=1)
print(predict)
np.argmax(predict)  #argmax function returns the index of maximum value in a numpy array
# Out:
# 1/1 [==============================] - 0s 101ms/step
# [[5.8407550e-06 5.0098967e-04 2.3073320e-04 9.7210014e-01 2.4833696e-06
#   2.5942689e-02 1.8796567e-06 4.1679363e-05 3.2565449e-04 8.4793125e-04]]
# 3
